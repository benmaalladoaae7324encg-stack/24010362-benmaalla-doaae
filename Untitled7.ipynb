# %% [markdown]
# <a href="https://colab.research.google.com/github/benmaalladoaae7324encg-stack/24010362-benmaalla-doaae/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import cv2
import random
import shutil
import matplotlib.pyplot as plt
from base64 import b64encode
from IPython.display import HTML, display

import warnings
warnings.filterwarnings("ignore")

os.environ['OMP_NUM_THREADS'] = '1'

# %%
# !pip install -U ipywidgets
# !pip install ultralytics
# !pip install torch
# !pip install wandb

# %%
from ultralytics import YOLO
import torch.multiprocessing as mp
mp.set_start_method('spawn', force=True)

# !wandb disabled
# Out:
# W&B disabled.

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# ====== INSTALL (exécuter une fois) ======
# !pip install -q ultralytics
# !pip install -q ipywidgets
# !pip install -q wandb

# ====== IMPORTS ======
import os, sys, shutil, json, yaml
import numpy as np
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import warnings
warnings.filterwarnings("ignore")

# Force safe number of threads
os.environ['OMP_NUM_THREADS'] = '1'
